# %%
import sys
sys.path.append('/home/brunelle/anaconda3/envs/env_two/lib/python3.9/site-packages')

import opendatasets as od
import pandas # data processing, CSV file I/O (e.g. pd.read_csv)
    
od.download("https://www.kaggle.com/datasets/prasad22/healthcare-dataset/data")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: brunelleagboton
# Your Kaggle Key: ········
# ...
# 100%|██████████████████████████████████████████████████████████████████████| 483k/483k [00:00<00:00, 1.16MB/s]

# %%
import pandas as pd
 
# reading the csv file
file =('healthcare-dataset/healthcare_dataset.csv')
newData = pd.read_csv(file)
 
# displaying the contents of the csv file
#newData.head()

#Add a new column
for date in['Date of Admission', 'Discharge Date']:
  newData[date]=pd.to_datetime(newData[date])

newData['Length of Stay'] = newData['Discharge Date'] - newData['Date of Admission']
newData['Length of Stay']

newData.shape
# Out:
#                   Name  Age  Gender Blood Type Medical Condition  \
# 0      Tiffany Ramirez   81  Female         O-          Diabetes
# 1          Ruben Burns   35    Male         O+            Asthma
# 2            Chad Byrd   61    Male         B-           Obesity
# 3    Antonio Frederick   49    Male         B-            Asthma
# 4  Mrs. Brandy Flowers   51    Male         O-         Arthritis
#
#   Date of Admission          Doctor                   Hospital  \
# 0        2022-11-17  Patrick Parker           Wallace-Hamilton
# 1        2023-06-01   Diane Jackson  Burke, Griffin and Cooper
# 2        2019-01-09      Paul Baker                 Walton LLC
# 3        2020-05-02  Brian Chandler                 Garcia Ltd
# 4        2021-07-09  Dustin Griffin    Jones, Brown and Murray
#
#   Insurance Provider  Billing Amount  Room Number Admission Type  \
# 0           Medicare    37490.983364          146       Elective
# ...
